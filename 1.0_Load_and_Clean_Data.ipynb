# %%
import pandas as pd
import os

# 1. Definiera sökvägen till filen
file_path = os.path.join('data', 'df_trips_combined.parquet')

try:
    # 2. Läs in Parquet-filen till en DataFrame
    df_trips = pd.read_parquet(file_path)
    
    print(f"✅ Filen '{file_path}' laddades in framgångsrikt.")
    print(f"Antal rader i DataFrame: {len(df_trips):,}")
    print("\nFörsta 5 raderna:")
    
    # 3. Skriv ut de första 5 raderna för att inspektera datat
    display(df_trips.head())
    
    # 4. Visa information om kolumner och datatyper (bra för datatvätt)
    print("\nKolumninformation:")
    df_trips.info()
    
except FileNotFoundError:
    print(f"❌ Fel: Filen hittades inte på sökvägen '{file_path}'. Kontrollera filnamnet och mappen.")
except Exception as e:
    print(f"❌ Ett oväntat fel uppstod: {e}")
# Out:
# ✅ Filen 'data\df_trips_combined.parquet' laddades in framgångsrikt.
# Antal rader i DataFrame: 66
#
# Första 5 raderna:
#      AdvertisedTrainIdent    TripDate       start_planned        start_actual  \
# 3294                 2870  2025-10-07 2025-10-07 19:06:00 2025-10-07 19:06:00
# 2750                 2564  2025-10-07 2025-10-07 17:51:00 2025-10-07 17:53:12
# 2361                 2264  2025-10-07 2025-10-07 17:40:00 2025-10-07 17:40:22
# 3280                 2864  2025-10-07 2025-10-07 17:36:00 2025-10-07 17:36:00
# 3122                 2764  2025-10-07 2025-10-07 17:28:00 2025-10-07 17:28:30
#
#      start_station start_owner start_operator         end_planned  \
# 3294           Bkb          SL            SLL 2025-10-07 20:10:00
# 2750           Bkb          SL            SLL 2025-10-07 19:06:00
# 2361          Arnc          SL            SLL 2025-10-07 19:04:00
# 3280           Bkb          SL            SLL 2025-10-07 18:40:00
# 3122           Bra          SL            SLL 2025-10-07 18:52:00
#
#               end_actual end_station  final_delay_min  any_canceled end_owner  \
# 3294 2025-10-07 21:05:05          Äs             0.75          True        SL
# 2750 2025-10-07 19:12:26          Äs             2.60          True        SL
# 2361 2025-10-07 19:09:16          Äs            -1.88          True        SL
# 3280 2025-10-07 18:43:57          Äs             0.03          True        SL
# 3122 2025-10-07 19:02:43         Öte            -0.55          True        SL
#
#      end_operator  duration_min  Delay_Minutes  delay_delta_check  start_hour  \
# 3294          SLL    119.083333      55.083333          54.333333          19
# 2750          SLL     79.233333       6.433333           3.833333          17
# 2361          SLL     88.900000       5.266667           7.146667          17
# 3280          SLL     67.950000       3.950000           3.920000          17
# 3122          SLL     94.216667      10.716667          11.266667          17
#
#       start_weekday  start_month
# 3294              1           10
# 2750              1           10
# 2361              1           10
# 3280              1           10
# 3122              1           10
# Kolumninformation:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 3294 to 6050
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AdvertisedTrainIdent  66 non-null     object
#  1   TripDate              66 non-null     object
#  2   start_planned         66 non-null     datetime64[ns]
#  3   start_actual          66 non-null     datetime64[ns]
#  4   start_station         66 non-null     object
#  5   start_owner           66 non-null     object
#  6   start_operator        66 non-null     object
#  7   end_planned           66 non-null     datetime64[ns]
#  8   end_actual            66 non-null     datetime64[ns]
#  9   end_station           66 non-null     object
#  10  final_delay_min       66 non-null     float64
#  11  any_canceled          66 non-null     boolean
#  12  end_owner             66 non-null     object
#  13  end_operator          66 non-null     object
#  14  duration_min          66 non-null     float64
#  15  Delay_Minutes         66 non-null     float64
#  16  delay_delta_check     66 non-null     float64
#  17  start_hour            66 non-null     int32
#  18  start_weekday         66 non-null     int32
#  19  start_month           66 non-null     int32
# dtypes: boolean(1), datetime64[ns](4), float64(4), int32(3), object(8)
# memory usage: 9.7+ KB
